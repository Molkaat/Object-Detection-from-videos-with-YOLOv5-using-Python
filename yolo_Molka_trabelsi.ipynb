# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16094, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 16094 (delta 0), reused 4 (delta 0), pack-reused 16089
# Receiving objects: 100% (16094/16094), 14.76 MiB | 12.97 MiB/s, done.
# Resolving deltas: 100% (11024/11024), done.

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
# %ls
# Out:
# benchmarks.py    data/       LICENSE          requirements.txt  tutorial.ipynb
# CITATION.cff     detect.py   models/          segment/          utils/
# classify/        export.py   README.md        setup.cfg         val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %%
# !pip install -r /content/yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %%
# !python /content/yolov5/detect.py --weights yolov5s.pt --source /content/drive/MyDrive/video/Cars.mp4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/video/Cars.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu118 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 131MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/755) /content/drive/MyDrive/video/Cars.mp4: 384x640 (no detections), 277.2ms
# video 1/1 (2/755) /content/drive/MyDrive/video/Cars.mp4: 384x640 (no detections), 276.3ms
# video 1/1 (3/755) /content/drive/MyDrive/video/Cars.mp4: 384x640 (no detections), 253.3ms
# ...

# %%
# Out:
# Mounted at /content/drive
